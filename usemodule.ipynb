# %%
import om as o

# %%
print(o.bhegakaro(10,5))
print(o.badkaro(10,5))
print(o.guniyakaro(10,5))
print(o.bhagyakaro(10,0))
# Out:
# 15
# 5
# 50
# Error: cannot divide by zero

# %%
try:
    a = int(input("Enter number: "))
    b = int(input("Enter number: "))
    print(a / b)
except ValueError:
    print("Invalid input")
except ZeroDivisionError:
    print("Cannot divide by zero")
# Out:
# Enter number:  1
# Enter number:  2d
# Invalid input
